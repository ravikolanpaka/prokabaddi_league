# %%
import json
import os
import pandas as pd

# %%
rootdir = "/Users/rk647f/ravikiran/personal/ProKabaddi-master/team_player_stats/all_seasons/team/"

# %%
paths = []
for root, dirs, files in os.walk(rootdir):
    for name in files:
        if name.endswith((".json")):
            full_path = os.path.join(root, name)
            paths.append(full_path)
            """with open(full_path) as json_file:
                data = json.load(json_file)
                doc_data = data["data"]
                team_ids = []
                for doc in doc_data:
                    team_ids.append(doc["team_id"])
                print(team_ids)"""

# %%
def declare_empty_jsons():
    team_ids = [6, 2, 7, 1, 4, 8, 3, 5, 30, 29, 28, 31]
    all_jsons = {}
    for ids in team_ids:
        all_jsons[ids] = []
    return(all_jsons)

# %%
def get_doc_data(doc):
    new_dict = {}
    team_name = doc["team_name"]
    team_id = doc["team_id"]
    new_dict["team_name"] = team_name
    match_played = doc["match_played"]
    new_dict["match_played"] = match_played
    value = doc["value"]
    new_dict[stat] = value
    rank = doc["rank"]
    new_dict["rank"] = rank
    
    return(team_id,new_dict)

# %%
def get_data(new_dict,all_jsons):
    stat = new_dict["stat"]
    stat_id = new_dict["stat_id"]
    minimum_criteria = new_dict["minimum_criteria"]
    data = new_dict["data"]
    print(stat)
    for doc in data:
        
        team_id,new_dict = get_doc_data(doc)
        all_jsons[team_id].append(new_dict)
        
    return(all_jsons)

# %%
all_jsons = declare_empty_jsons()

# %%
all_jsons
# Out:
# {6: [],
#  2: [],
#  7: [],
#  1: [],
#  4: [],
#  8: [],
#  3: [],
#  5: [],
#  30: [],
#  29: [],
#  28: [],
#  31: []}

# %%
full_data = {}
for path in paths:
    
    with open(path) as json_file:
        data = json.load(json_file)
        stat = data["stat"]
        stat_id = data["stat_id"]
        minimum_criteria = data["minimum_criteria"]
        data = data["data"]
        print(stat)
        for doc in data:

            team_id,new_dict = get_doc_data(doc)
            all_jsons[team_id].append(new_dict)
# Out:
# Team Total Points Conceded
# Team All-outs Conceded
# Team All-outs Inflicted
# Team Avg Points Scored
# Team Tackle Points
# Team Average Tackle Points
# Team Total Points
# Team DOD Raid Points
# Team Super Tackles
# Team Super Raid
# Team Successful Raids
# Team Raid Points
# Team Successful Tackles
# Team Average Raid Points

# %%
all_jsons
# Out:
# {6: [{'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Total Points Conceded': 4225,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team All-outs Conceded': 141,
#    'rank': '4'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team All-outs Inflicted': 191,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Avg Points Scored': 30,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Tackle Points': 1291,
#    'rank': '2'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Average Tackle Points': 10.01,
#    'rank': '4'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Total Points': 4450,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team DOD Raid Points': 461,
#    'rank': '2'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Super Tackles': 130,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Super Raid': 88,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Successful Raids': 2025,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Raid Points': 2579,
#    'rank': '1'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Successful Tackles': 1165,
#    'rank': '2'},
#   {'team_name': 'Patna Pirates',
#    'match_played': 129,
#    'Team Average Raid Points': 19.99,
#    'rank': '1'}],
#  2: [{'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Total Points Conceded': 3926,
#    'rank': '2'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team All-outs Conceded': 162,
#    'rank': '1'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team All-outs Inflicted': 133,
#    'rank': '6'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Avg Points Scored': 26.82,
#    'rank': '9'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Tackle Points': 1048,
#    'rank': '8'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Average Tackle Points': 8.88,
#    'rank': '11'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Total Points': 3642,
#    'rank': '8'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team DOD Raid Points': 438,
#    'rank': '7'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Super Tackles': 95,
#    'rank': '7'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Super Raid': 61,
#    'rank': '6'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Successful Raids': 1698,
#    'rank': '6'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Raid Points': 2117,
#    'rank': '6'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Successful Tackles': 960,
#    'rank': '8'},
#   {'team_name': 'Dabang Delhi K.C.',
#    'match_played': 118,
#    'Team Average Raid Points': 17.94,
#    'rank': '8'}],
#  7: [{'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Total Points Conceded': 3922,
#    'rank': '3'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team All-outs Conceded': 156,
#    'rank': '2'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team All-outs Inflicted': 133,
#    'rank': '6'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Avg Points Scored': 26.78,
#    'rank': '10'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Tackle Points': 1255,
#    'rank': '3'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Average Tackle Points': 10.12,
#    'rank': '3'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Total Points': 3814,
#    'rank': '5'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team DOD Raid Points': 518,
#    'rank': '1'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Super Tackles': 122,
#    'rank': '3'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Super Raid': 63,
#    'rank': '3'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Successful Raids': 1651,
#    'rank': '7'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Raid Points': 2066,
#    'rank': '7'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Successful Tackles': 1141,
#    'rank': '3'},
#   {'team_name': 'Puneri Paltan',
#    'match_played': 124,
#    'Team Average Raid Points': 16.66,
#    'rank': '12'}],
#  1: [{'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Total Points Conceded': 3835,
#    'rank': '4'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team All-outs Conceded': 143,
#    'rank': '3'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team All-outs Inflicted': 149,
#    'rank': '3'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Avg Points Scored': 27.6,
#    'rank': '7'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Tackle Points': 1152,
#    'rank': '6'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Average Tackle Points': 9.37,
#    'rank': '9'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Total Points': 3886,
#    'rank': '3'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team DOD Raid Points': 449,
#    'rank': '4'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Super Tackles': 93,
#    'rank': '8'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Super Raid': 62,
#    'rank': '4'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Successful Raids': 1779,
#    'rank': '3'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Raid Points': 2244,
#    'rank': '2'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Successful Tackles': 1066,
#    'rank': '4'},
#   {'team_name': 'Bengaluru Bulls',
#    'match_played': 123,
#    'Team Average Raid Points': 18.24,
#    'rank': '5'}],
#  4: [{'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Total Points Conceded': 3834,
#    'rank': '5'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team All-outs Conceded': 141,
#    'rank': '4'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team All-outs Inflicted': 126,
#    'rank': '8'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Avg Points Scored': 26.63,
#    'rank': '11'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Tackle Points': 1092,
#    'rank': '7'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Average Tackle Points': 8.95,
#    'rank': '10'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Total Points': 3704,
#    'rank': '7'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team DOD Raid Points': 444,
#    'rank': '6'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Super Tackles': 98,
#    'rank': '6'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Super Raid': 68,
#    'rank': '2'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Successful Raids': 1725,
#    'rank': '5'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Raid Points': 2158,
#    'rank': '5'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Successful Tackles': 999,
#    'rank': '7'},
#   {'team_name': 'Bengal Warriors',
#    'match_played': 122,
#    'Team Average Raid Points': 17.69,
#    'rank': '9'}],
#  8: [{'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Total Points Conceded': 3790,
#    'rank': '6'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team All-outs Conceded': 130,
#    'rank': '8'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team All-outs Inflicted': 138,
#    'rank': '4'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Avg Points Scored': 28.17,
#    'rank': '4'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Tackle Points': 1157,
#    'rank': '4'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Average Tackle Points': 9.64,
#    'rank': '6'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Total Points': 3833,
#    'rank': '4'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team DOD Raid Points': 425,
#    'rank': '8'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Super Tackles': 115,
#    'rank': '4'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Super Raid': 58,
#    'rank': '8'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Successful Raids': 1798,
#    'rank': '2'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Raid Points': 2224,
#    'rank': '3'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Successful Tackles': 1048,
#    'rank': '5'},
#   {'team_name': 'Telugu Titans',
#    'match_played': 120,
#    'Team Average Raid Points': 18.53,
#    'rank': '3'}],
#  3: [{'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Total Points Conceded': 3755,
#    'rank': '7'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team All-outs Conceded': 139,
#    'rank': '6'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team All-outs Inflicted': 134,
#    'rank': '5'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Avg Points Scored': 26.61,
#    'rank': '12'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Tackle Points': 1155,
#    'rank': '5'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Average Tackle Points': 9.55,
#    'rank': '8'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Total Points': 3714,
#    'rank': '6'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team DOD Raid Points': 461,
#    'rank': '2'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Super Tackles': 129,
#    'rank': '2'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Super Raid': 60,
#    'rank': '7'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Successful Raids': 1628,
#    'rank': '8'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Raid Points': 2066,
#    'rank': '7'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Successful Tackles': 1031,
#    'rank': '6'},
#   {'team_name': 'Jaipur Pink Panthers',
#    'match_played': 121,
#    'Team Average Raid Points': 17.07,
#    'rank': '11'}],
#  5: [{'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Total Points Conceded': 3638,
#    'rank': '8'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team All-outs Conceded': 135,
#    'rank': '7'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team All-outs Inflicted': 167,
#    'rank': '2'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Avg Points Scored': 28.46,
#    'rank': '3'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Tackle Points': 1293,
#    'rank': '1'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Average Tackle Points': 10.51,
#    'rank': '2'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Total Points': 4001,
#    'rank': '2'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team DOD Raid Points': 446,
#    'rank': '5'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Super Tackles': 102,
#    'rank': '5'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Super Raid': 62,
#    'rank': '4'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Successful Raids': 1753,
#    'rank': '4'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Raid Points': 2208,
#    'rank': '4'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Successful Tackles': 1193,
#    'rank': '1'},
#   {'team_name': 'U Mumba',
#    'match_played': 123,
#    'Team Average Raid Points': 17.95,
#    'rank': '7'}],
#  30: [{'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Total Points Conceded': 2150,
#    'rank': '9'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team All-outs Conceded': 83,
#    'rank': '10'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team All-outs Inflicted': 69,
#    'rank': '10'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Avg Points Scored': 28.07,
#    'rank': '5'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Tackle Points': 646,
#    'rank': '10'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Average Tackle Points': 9.94,
#    'rank': '5'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Total Points': 2088,
#    'rank': '10'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team DOD Raid Points': 233,
#    'rank': '9'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Super Tackles': 60,
#    'rank': '9'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Super Raid': 37,
#    'rank': '9'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Successful Raids': 923,
#    'rank': '12'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Raid Points': 1179,
#    'rank': '9'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Successful Tackles': 590,
#    'rank': '10'},
#   {'team_name': 'U.P. Yoddha',
#    'match_played': 65,
#    'Team Average Raid Points': 18.14,
#    'rank': '6'}],
#  29: [{'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Total Points Conceded': 2102,
#    'rank': '10'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team All-outs Conceded': 84,
#    'rank': '9'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team All-outs Inflicted': 52,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Avg Points Scored': 27.2,
#    'rank': '8'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Tackle Points': 545,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Average Tackle Points': 8.79,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Total Points': 1877,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team DOD Raid Points': 207,
#    'rank': '11'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Super Tackles': 45,
#    'rank': '11'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Super Raid': 16,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Successful Raids': 943,
#    'rank': '9'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Raid Points': 1142,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Successful Tackles': 502,
#    'rank': '12'},
#   {'team_name': 'Tamil Thalaivas',
#    'match_played': 62,
#    'Team Average Raid Points': 18.42,
#    'rank': '4'}],
#  28: [{'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Total Points Conceded': 2050,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team All-outs Conceded': 75,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team All-outs Inflicted': 65,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Avg Points Scored': 28.7,
#    'rank': '2'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Tackle Points': 588,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Average Tackle Points': 9.64,
#    'rank': '6'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Total Points': 1985,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team DOD Raid Points': 203,
#    'rank': '12'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Super Tackles': 47,
#    'rank': '10'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Super Raid': 36,
#    'rank': '10'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Successful Raids': 928,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Raid Points': 1163,
#    'rank': '10'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Successful Tackles': 543,
#    'rank': '11'},
#   {'team_name': 'Haryana Steelers',
#    'match_played': 61,
#    'Team Average Raid Points': 19.07,
#    'rank': '2'}],
#  31: [{'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Total Points Conceded': 1911,
#    'rank': '12'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team All-outs Conceded': 56,
#    'rank': '12'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team All-outs Inflicted': 88,
#    'rank': '9'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Avg Points Scored': 27.9,
#    'rank': '6'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Tackle Points': 697,
#    'rank': '9'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Average Tackle Points': 10.56,
#    'rank': '1'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Total Points': 2144,
#    'rank': '9'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team DOD Raid Points': 222,
#    'rank': '10'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Super Tackles': 45,
#    'rank': '11'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Super Raid': 25,
#    'rank': '11'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Successful Raids': 942,
#    'rank': '10'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Raid Points': 1145,
#    'rank': '11'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Successful Tackles': 655,
#    'rank': '9'},
#   {'team_name': 'Gujarat Fortunegiants',
#    'match_played': 66,
#    'Team Average Raid Points': 17.35,
#    'rank': '10'}]}

# %%
columns = ["Team Total Points Conceded","Team All-outs Conceded","Team All-outs Inflicted","Team Avg Points Scored",
          "Team Average Tackle Points","Team Total Points","Team DOD Raid Points","Team Super Tackles"]

# %%
def merge_jsons(dict_jsons):
    
    result = {}
    for doc in dict_jsons:
        result.update(doc)
    return(result)

# %%
final_doc = {}
for key in all_jsons:
    
    final_doc[key] = merge_jsons(all_jsons[key])

# %%
final_doc
# Out:
# {6: {'team_name': 'Patna Pirates',
#   'match_played': 129,
#   'Team Total Points Conceded': 4225,
#   'rank': '1',
#   'Team All-outs Conceded': 141,
#   'Team All-outs Inflicted': 191,
#   'Team Avg Points Scored': 30,
#   'Team Tackle Points': 1291,
#   'Team Average Tackle Points': 10.01,
#   'Team Total Points': 4450,
#   'Team DOD Raid Points': 461,
#   'Team Super Tackles': 130,
#   'Team Super Raid': 88,
#   'Team Successful Raids': 2025,
#   'Team Raid Points': 2579,
#   'Team Successful Tackles': 1165,
#   'Team Average Raid Points': 19.99},
#  2: {'team_name': 'Dabang Delhi K.C.',
#   'match_played': 118,
#   'Team Total Points Conceded': 3926,
#   'rank': '8',
#   'Team All-outs Conceded': 162,
#   'Team All-outs Inflicted': 133,
#   'Team Avg Points Scored': 26.82,
#   'Team Tackle Points': 1048,
#   'Team Average Tackle Points': 8.88,
#   'Team Total Points': 3642,
#   'Team DOD Raid Points': 438,
#   'Team Super Tackles': 95,
#   'Team Super Raid': 61,
#   'Team Successful Raids': 1698,
#   'Team Raid Points': 2117,
#   'Team Successful Tackles': 960,
#   'Team Average Raid Points': 17.94},
#  7: {'team_name': 'Puneri Paltan',
#   'match_played': 124,
#   'Team Total Points Conceded': 3922,
#   'rank': '12',
#   'Team All-outs Conceded': 156,
#   'Team All-outs Inflicted': 133,
#   'Team Avg Points Scored': 26.78,
#   'Team Tackle Points': 1255,
#   'Team Average Tackle Points': 10.12,
#   'Team Total Points': 3814,
#   'Team DOD Raid Points': 518,
#   'Team Super Tackles': 122,
#   'Team Super Raid': 63,
#   'Team Successful Raids': 1651,
#   'Team Raid Points': 2066,
#   'Team Successful Tackles': 1141,
#   'Team Average Raid Points': 16.66},
#  1: {'team_name': 'Bengaluru Bulls',
#   'match_played': 123,
#   'Team Total Points Conceded': 3835,
#   'rank': '5',
#   'Team All-outs Conceded': 143,
#   'Team All-outs Inflicted': 149,
#   'Team Avg Points Scored': 27.6,
#   'Team Tackle Points': 1152,
#   'Team Average Tackle Points': 9.37,
#   'Team Total Points': 3886,
#   'Team DOD Raid Points': 449,
#   'Team Super Tackles': 93,
#   'Team Super Raid': 62,
#   'Team Successful Raids': 1779,
#   'Team Raid Points': 2244,
#   'Team Successful Tackles': 1066,
#   'Team Average Raid Points': 18.24},
#  4: {'team_name': 'Bengal Warriors',
#   'match_played': 122,
#   'Team Total Points Conceded': 3834,
#   'rank': '9',
#   'Team All-outs Conceded': 141,
#   'Team All-outs Inflicted': 126,
#   'Team Avg Points Scored': 26.63,
#   'Team Tackle Points': 1092,
#   'Team Average Tackle Points': 8.95,
#   'Team Total Points': 3704,
#   'Team DOD Raid Points': 444,
#   'Team Super Tackles': 98,
#   'Team Super Raid': 68,
#   'Team Successful Raids': 1725,
#   'Team Raid Points': 2158,
#   'Team Successful Tackles': 999,
#   'Team Average Raid Points': 17.69},
#  8: {'team_name': 'Telugu Titans',
#   'match_played': 120,
#   'Team Total Points Conceded': 3790,
#   'rank': '3',
#   'Team All-outs Conceded': 130,
#   'Team All-outs Inflicted': 138,
#   'Team Avg Points Scored': 28.17,
#   'Team Tackle Points': 1157,
#   'Team Average Tackle Points': 9.64,
#   'Team Total Points': 3833,
#   'Team DOD Raid Points': 425,
#   'Team Super Tackles': 115,
#   'Team Super Raid': 58,
#   'Team Successful Raids': 1798,
#   'Team Raid Points': 2224,
#   'Team Successful Tackles': 1048,
#   'Team Average Raid Points': 18.53},
#  3: {'team_name': 'Jaipur Pink Panthers',
#   'match_played': 121,
#   'Team Total Points Conceded': 3755,
#   'rank': '11',
#   'Team All-outs Conceded': 139,
#   'Team All-outs Inflicted': 134,
#   'Team Avg Points Scored': 26.61,
#   'Team Tackle Points': 1155,
#   'Team Average Tackle Points': 9.55,
#   'Team Total Points': 3714,
#   'Team DOD Raid Points': 461,
#   'Team Super Tackles': 129,
#   'Team Super Raid': 60,
#   'Team Successful Raids': 1628,
#   'Team Raid Points': 2066,
#   'Team Successful Tackles': 1031,
#   'Team Average Raid Points': 17.07},
#  5: {'team_name': 'U Mumba',
#   'match_played': 123,
#   'Team Total Points Conceded': 3638,
#   'rank': '7',
#   'Team All-outs Conceded': 135,
#   'Team All-outs Inflicted': 167,
#   'Team Avg Points Scored': 28.46,
#   'Team Tackle Points': 1293,
#   'Team Average Tackle Points': 10.51,
#   'Team Total Points': 4001,
#   'Team DOD Raid Points': 446,
#   'Team Super Tackles': 102,
#   'Team Super Raid': 62,
#   'Team Successful Raids': 1753,
#   'Team Raid Points': 2208,
#   'Team Successful Tackles': 1193,
#   'Team Average Raid Points': 17.95},
#  30: {'team_name': 'U.P. Yoddha',
#   'match_played': 65,
#   'Team Total Points Conceded': 2150,
#   'rank': '6',
#   'Team All-outs Conceded': 83,
#   'Team All-outs Inflicted': 69,
#   'Team Avg Points Scored': 28.07,
#   'Team Tackle Points': 646,
#   'Team Average Tackle Points': 9.94,
#   'Team Total Points': 2088,
#   'Team DOD Raid Points': 233,
#   'Team Super Tackles': 60,
#   'Team Super Raid': 37,
#   'Team Successful Raids': 923,
#   'Team Raid Points': 1179,
#   'Team Successful Tackles': 590,
#   'Team Average Raid Points': 18.14},
#  29: {'team_name': 'Tamil Thalaivas',
#   'match_played': 62,
#   'Team Total Points Conceded': 2102,
#   'rank': '4',
#   'Team All-outs Conceded': 84,
#   'Team All-outs Inflicted': 52,
#   'Team Avg Points Scored': 27.2,
#   'Team Tackle Points': 545,
#   'Team Average Tackle Points': 8.79,
#   'Team Total Points': 1877,
#   'Team DOD Raid Points': 207,
#   'Team Super Tackles': 45,
#   'Team Super Raid': 16,
#   'Team Successful Raids': 943,
#   'Team Raid Points': 1142,
#   'Team Successful Tackles': 502,
#   'Team Average Raid Points': 18.42},
#  28: {'team_name': 'Haryana Steelers',
#   'match_played': 61,
#   'Team Total Points Conceded': 2050,
#   'rank': '2',
#   'Team All-outs Conceded': 75,
#   'Team All-outs Inflicted': 65,
#   'Team Avg Points Scored': 28.7,
#   'Team Tackle Points': 588,
#   'Team Average Tackle Points': 9.64,
#   'Team Total Points': 1985,
#   'Team DOD Raid Points': 203,
#   'Team Super Tackles': 47,
#   'Team Super Raid': 36,
#   'Team Successful Raids': 928,
#   'Team Raid Points': 1163,
#   'Team Successful Tackles': 543,
#   'Team Average Raid Points': 19.07},
#  31: {'team_name': 'Gujarat Fortunegiants',
#   'match_played': 66,
#   'Team Total Points Conceded': 1911,
#   'rank': '10',
#   'Team All-outs Conceded': 56,
#   'Team All-outs Inflicted': 88,
#   'Team Avg Points Scored': 27.9,
#   'Team Tackle Points': 697,
#   'Team Average Tackle Points': 10.56,
#   'Team Total Points': 2144,
#   'Team DOD Raid Points': 222,
#   'Team Super Tackles': 45,
#   'Team Super Raid': 25,
#   'Team Successful Raids': 942,
#   'Team Raid Points': 1145,
#   'Team Successful Tackles': 655,
#   'Team Average Raid Points': 17.35}}

# %%
df = pd.DataFrame()

# %%
for key in final_doc:
    df.append
